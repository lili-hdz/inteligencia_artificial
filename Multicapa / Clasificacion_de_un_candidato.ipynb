# %% [markdown]
# <a href="https://colab.research.google.com/github/lili-hdz/inteligencia_artificial/blob/main/Multicapa%20/%20Clasificacion_de_un_candidato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicio Clasificacion de un candidato a un empleo
# Practica de redes neuronales / MULTICAPA
#
# ---
# Liliana Patricia Hernandez Cruz

# %% [markdown]
# Este un modelo que clasifica a un candidato a un empleo de acuerdo a sus habilidades. Se utiliza un cojunto de datos sintético.

# %% [markdown]
# # Generamos el Dataset sintético

# %%
import numpy as np
import pandas as pd

# Generar dataset sintético con diferentes rangos por habilidad
n_muestras = 5000
# Habilidades técnicas: 70-100
tec = np.random.randint(70, 101, (n_muestras, 6))
# Habilidades matemáticas: 60-90
mat = np.random.randint(60, 91, (n_muestras, 6))
# Habilidades psicológicas: 50-85
psi = np.random.randint(50, 86, (n_muestras, 6))
# Nombres de columnas
columnas = [
    'python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube',
    'estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado',
    'trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas'
]
# Crear DataFrame
df = pd.DataFrame(np.concatenate([tec, mat, psi], axis=1), columns=columnas)

# %%
# Calcular promedio por grupo y promedio total
prom_tecnologicas = df[['python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube']].mean(axis=1)
prom_matematicas  = df[['estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado']].mean(axis=1)
prom_psicologicas = df[['trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas']].mean(axis=1)
# Promedio total = promedio de los 3 promedios
prom_total = (prom_tecnologicas + prom_matematicas + prom_psicologicas) / 3
# Etiqueta: 1 = apto si promedio total > 80
y = (prom_total > 75).astype(int)
# one-hot encoding
y = pd.get_dummies(y).values

# %% [markdown]
# Separamos los conjuntos de entrenamiento

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42
)
#Separamos el 20% de nuestros datos para usarlo de prueba

# Escalamiento
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

##Ayuda a que los datos tengan una media de 0 y una desv. estandár de 1
#(.fit) es para la desv. estandár

# %% [markdown]
# Red Neuronal

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
modelo = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')
])

#Utilizamos 4 capas de las cuales, 3 están ocultas y la capa de salida tiene 2 neuronas.
#Optimizamos el modelo con Adam y lo compilamos con (.compile)
adam = Adam(learning_rate=0.001)
modelo.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Entrenamiento

# %%
history = modelo.fit(
    X_train, y_train,
    epochs=50,
    batch_size=8,
    validation_data=(X_test, y_test),
    verbose=1
)
#Entrenamos el modelo con (.fit) y con 50 épocas.
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7819 - loss: 0.4291 - val_accuracy: 0.9400 - val_loss: 0.1261
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9660 - loss: 0.0812 - val_accuracy: 0.9660 - val_loss: 0.0773
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9839 - loss: 0.0442 - val_accuracy: 0.9670 - val_loss: 0.0834
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9859 - loss: 0.0392 - val_accuracy: 0.9680 - val_loss: 0.0757
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9948 - loss: 0.0180 - val_accuracy: 0.9690 - val_loss: 0.0869
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9927 - loss: 0.0209 - val_accuracy: 0.9630 - val_loss: 0.0884
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9947 - loss: 0.0122 - val_accuracy: 0.9650 - val_loss: 0.0896
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9951 - loss: 0.0143 - val_accuracy: 0.9720 - val_loss: 0.0893
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9962 - loss: 0.0105 - val_accuracy: 0.9640 - val_loss: 0.1248
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9973 - loss: 0.0088 - val_accuracy: 0.9680 - val_loss: 0.1121
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9903 - loss: 0.0269 - val_accuracy: 0.9710 - val_loss: 0.0922
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9964 - loss: 0.0102 - val_accuracy: 0.9620 - val_loss: 0.1066
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9966 - loss: 0.0089 - val_accuracy: 0.9760 - val_loss: 0.0799
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9790 - val_loss: 0.0626
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 9.1686e-04 - val_accuracy: 0.9790 - val_loss: 0.0692
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 1.0000 - loss: 4.8181e-04 - val_accuracy: 0.9760 - val_loss: 0.0719
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 1.9847e-04 - val_accuracy: 0.9790 - val_loss: 0.0697
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 1.7514e-04 - val_accuracy: 0.9770 - val_loss: 0.0729
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 1.1194e-04 - val_accuracy: 0.9770 - val_loss: 0.0751
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 1.0000 - loss: 7.8048e-05 - val_accuracy: 0.9790 - val_loss: 0.0786
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 6.5081e-05 - val_accuracy: 0.9740 - val_loss: 0.0827
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 4.6568e-05 - val_accuracy: 0.9790 - val_loss: 0.0867
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.1009e-05 - val_accuracy: 0.9780 - val_loss: 0.0891
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 2.3768e-05 - val_accuracy: 0.9750 - val_loss: 0.0923
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.8847e-05 - val_accuracy: 0.9750 - val_loss: 0.0940
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.6005e-05 - val_accuracy: 0.9760 - val_loss: 0.0995
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 9.4842e-06 - val_accuracy: 0.9760 - val_loss: 0.1005
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 9.1485e-06 - val_accuracy: 0.9760 - val_loss: 0.1037
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.6797e-06 - val_accuracy: 0.9750 - val_loss: 0.1063
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.8450e-06 - val_accuracy: 0.9760 - val_loss: 0.1082
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.4635e-06 - val_accuracy: 0.9750 - val_loss: 0.1101
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 1.0000 - loss: 2.8555e-06 - val_accuracy: 0.9740 - val_loss: 0.1154
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.9278e-06 - val_accuracy: 0.9750 - val_loss: 0.1218
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 1.4661e-06 - val_accuracy: 0.9750 - val_loss: 0.1217
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.0024e-06 - val_accuracy: 0.9750 - val_loss: 0.1260
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.0995e-07 - val_accuracy: 0.9750 - val_loss: 0.1282
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 6.1965e-07 - val_accuracy: 0.9750 - val_loss: 0.1297
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.8985e-07 - val_accuracy: 0.9750 - val_loss: 0.1328
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.5770e-07 - val_accuracy: 0.9760 - val_loss: 0.1367
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.8373e-07 - val_accuracy: 0.9730 - val_loss: 0.1408
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.7389e-07 - val_accuracy: 0.9760 - val_loss: 0.1477
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3579e-07 - val_accuracy: 0.9740 - val_loss: 0.1480
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0147e-07 - val_accuracy: 0.9750 - val_loss: 0.1521
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.0090e-08 - val_accuracy: 0.9750 - val_loss: 0.1526
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 6.1174e-08 - val_accuracy: 0.9760 - val_loss: 0.1518
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 5.4313e-08 - val_accuracy: 0.9760 - val_loss: 0.1551
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.1196e-08 - val_accuracy: 0.9750 - val_loss: 0.1603
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.7243e-08 - val_accuracy: 0.9760 - val_loss: 0.1609
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 2.0299e-08 - val_accuracy: 0.9750 - val_loss: 0.1654
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 1.0000 - loss: 1.6706e-08 - val_accuracy: 0.9770 - val_loss: 0.1657

# %% [markdown]
# Evaluación

# %%
import matplotlib.pyplot as plt #importamos nuestra libreria para tener mejor visualización del modelo

plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title('Evolución de la función de pérdida')
plt.show()

#Evaluamos el modelo con (.evaluate) y nos dara el resultado con 4 decimales.
loss, acc = modelo.evaluate(X_test, y_test)
print(f"\n🔹 Loss: {loss:.4f}  |  Accuracy: {acc:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9727 - loss: 0.2274
#
# 🔹 Loss: 0.1657  |  Accuracy: 0.9770

# %% [markdown]
# Matriz de Confusión

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score

pred = modelo.predict(X_test)
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Apto', 'Apto'])
disp.plot(cmap='Blues')
plt.show()

sensitivity = recall_score(y_true, y_pred, average=None)
print("\nSensitivity (Recall) por clase:")
print(f"No Apto: {sensitivity[0]:.2f}")
print(f"Apto: {sensitivity[1]:.2f}")
#La matriz nos sirve para visualizar mejor la sensibilidad (recall) de nuestro modelo y saber si es efectivo.
#En este caso pareciera que el modelo esta bien ya que el recall esta muy cercano a 1
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Sensitivity (Recall) por clase:
# No Apto: 0.97
# Apto: 0.98

# %% [markdown]
# Evaluar un nuevo candidato

# %%
nuevo_candidato = np.array([[90, 88, 85, 87, 84, 89,   # técnicas
                             82, 86, 85, 83, 87, 80,   # matemáticas
                             70, 75, 80, 72, 78, 74]]) # psicológicas

nuevo_candidato_scaled = scaler.transform(nuevo_candidato)
pred_nuevo = modelo.predict(nuevo_candidato_scaled)
clase_predicha = np.argmax(pred_nuevo)

print("Evaluación de nuevo candidato:")
print(f"Resultado: {'Apto' if clase_predicha == 1 else 'No Apto'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Evaluación de nuevo candidato:
# Resultado: Apto
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
